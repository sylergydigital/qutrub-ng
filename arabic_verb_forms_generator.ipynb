# %% [markdown]
# # Arabic Verb Forms Generator (I-X)
#
# This notebook generates all 10 Arabic verb forms from a given root verb.
#
# ## The 10 Arabic Verb Forms:
#
# 1. **Form I (الفعل المجرد)**: The basic or original root form
# 2. **Form II (فَعَّلَ)**: Often conveys causative or intensive meaning
# 3. **Form III (فَاعَلَ)**: Usually indicates interaction or reciprocity
# 4. **Form IV (أفْعَلَ)**: Typically has causative or declarative meanings
# 5. **Form V (تَفَعَّلَ)**: Generally a reflexive or intensive of Form II
# 6. **Form VI (تَفاعَلَ)**: Reflexive or reciprocal of Form III
# 7. **Form VII (اِنْفَعَلَ)**: Often passive or reflexive
# 8. **Form VIII (اِفْتَعَلَ)**: Reflexive or related to taking part in the action
# 9. **Form IX (اِفْعَلَّ)**: Rare; usually relates to colors or physical defects
# 10. **Form X (اِسْتَفْعَلَ)**: Implies seeking or asking for the action of the root

# %% [markdown]
# ## Setup
#
# First, install the required packages (run once):

# %%
# Install required packages
# !pip install pyarabic
# !pip install libqutrub

# %% [markdown]
# Import the necessary libraries:

# %%
# Import libraries
import libqutrub.conjugator
import libqutrub.verb_valid

print("✅ Libraries loaded successfully!")

# %% [markdown]
# ## Generate Verb Forms Table
#
# **Instructions:**
# 1. Enter your Arabic root verb in the `ROOT_VERB` variable below
# 2. The verb must be properly vocalized (with fatha, damma, kasra)
# 3. Use a 3-letter root verb (triliteral/مُثَلَّث)
# 4. Run the cell to see all 10 verb forms
#
# **Example verbs to try:**
# - `كَتَبَ` (k-t-b: to write)
# - `ضَرَبَ` (d-r-b: to hit)
# - `سَمِعَ` (s-m-ʿ: to hear)
# - `فَعَلَ` (f-ʿ-l: to do)
# - `عَلِمَ` (ʿ-l-m: to know)
# - `كَسَرَ` (k-s-r: to break)
# - `ذَهَبَ` (dh-h-b: to go)
# - `قَرَأَ` (q-r-ʾ: to read)
# - `شَرِبَ` (sh-r-b: to drink)
# - `جَلَسَ` (j-l-s: to sit)

# %%
# ═══════════════════════════════════════════════════════════════
# 🔧 ENTER YOUR ARABIC ROOT VERB HERE:
# ═══════════════════════════════════════════════════════════════

ROOT_VERB = "كَتَبَ"  # <-- CHANGE THIS TO YOUR VERB

# ═══════════════════════════════════════════════════════════════

print("\n" + "═" * 70)
print(f"🔍 Generating All 10 Verb Forms for: {ROOT_VERB}")
print("═" * 70 + "\n")

# Validate the verb first
is_valid = libqutrub.verb_valid.is_valid_infinitive_verb(ROOT_VERB)

if not is_valid:
    print("❌ ERROR: Invalid verb format!\n")
    print("Please make sure:")
    print("  • The verb is properly vocalized (includes fatha, damma, or kasra)")
    print("  • It's a 3-letter root verb (triliteral)")
    print("  • Example: كَتَبَ (not كتب)\n")
else:
    print("✅ Valid verb format detected\n")
    
    try:
        # Generate the verb forms table
        forms_table = libqutrub.conjugator.conjugate(
            word=ROOT_VERB,
            future_type="ضمة",  # Default future type (damma)
            display_format="FORM_TABLE",
            transitive=True
        )
        
        print("📊 ARABIC VERB FORMS (I-X)")
        print("═" * 70)
        print(forms_table)
        print("═" * 70)
        
        print("\n✨ Success! All 10 verb forms generated.\n")
        
        # Display form descriptions
        print("📚 FORM DESCRIPTIONS:")
        print("─" * 70)
        descriptions = [
            ("I", "الفعل المجرد", "Basic root form"),
            ("II", "فَعَّلَ", "Causative/intensive"),
            ("III", "فَاعَلَ", "Interaction/reciprocity"),
            ("IV", "أفْعَلَ", "Causative/declarative"),
            ("V", "تَفَعَّلَ", "Reflexive/intensive of II"),
            ("VI", "تَفاعَلَ", "Reflexive/reciprocal of III"),
            ("VII", "اِنْفَعَلَ", "Passive/reflexive"),
            ("VIII", "اِفْتَعَلَ", "Reflexive/participatory"),
            ("IX", "اِفْعَلَّ", "Colors/physical defects (rare)"),
            ("X", "اِسْتَفْعَلَ", "Seeking/asking for action")
        ]
        
        for num, pattern, desc in descriptions:
            print(f"  Form {num:>3} ({pattern:>10}): {desc}")
        
        print("\n💡 TIP: Change the ROOT_VERB above and run again to try different verbs!\n")
        
    except Exception as e:
        print(f"❌ ERROR: {e}\n")
        print("🔧 TROUBLESHOOTING:")
        print("  • Ensure libqutrub is properly installed")
        print("  • Try a different root verb")
        print("  • Make sure the verb is properly vocalized")
        print(f"  • Example: كَتَبَ (to write)\n")

# %% [markdown]
# ## Try Multiple Verbs
#
# You can also generate forms for multiple verbs at once:

# %%
# List of verbs to process
verbs_to_process = [
    "كَتَبَ",  # to write
    "ضَرَبَ",  # to hit
    "سَمِعَ",  # to hear
    "قَرَأَ",  # to read
]

print("\n" + "═" * 70)
print("📚 BATCH PROCESSING: Generating Forms for Multiple Verbs")
print("═" * 70 + "\n")

for verb in verbs_to_process:
    print(f"\n🔹 Verb: {verb}")
    print("─" * 70)
    
    if libqutrub.verb_valid.is_valid_infinitive_verb(verb):
        try:
            forms_table = libqutrub.conjugator.conjugate(
                word=verb,
                future_type="ضمة",
                display_format="FORM_TABLE",
                transitive=True
            )
            print(forms_table)
        except Exception as e:
            print(f"❌ Error: {e}")
    else:
        print("❌ Invalid verb format")
    
    print("─" * 70)

print("\n✅ Batch processing complete!\n")

# %% [markdown]
# ---
#
# ## Notes
#
# - Not all verbs have all 10 forms. Some forms may not exist for certain roots.
# - Form IX is rare and primarily used for colors and physical characteristics.
# - The table shows the past tense (مَاضِي) form of each verb form.
# - For full conjugation tables (all tenses, pronouns, etc.), use the main `qutrub_notebook.ipynb`.
#
# ---
#
# **Powered by Qutrub** - Arabic Verb Conjugation Library
